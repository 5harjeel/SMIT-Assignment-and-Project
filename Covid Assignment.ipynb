# %% [markdown]
# # Tasks for Data Visualization

# %% [markdown]
# # 1

# %%
import pandas as pd
df=pd.DataFrame()
df=pd.read_csv("C:/Saylani stuff/covid_19_country_wise_latest.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# 0           0    Afghanistan      36263   1269      25198    9796      106.0
# 1           1        Albania       4880    144       2745    1991      117.0
# 2           2        Algeria      27973   1163      18837    7973      616.0
# 3           3        Andorra        907     52        803      52       10.0
# 4           4         Angola        950     41        242     667       18.0
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0        10.0             18                3.50                  69.49
# 1         6.0             63                2.95                  56.25
# 2         8.0            749                4.16                  67.34
# 3         0.0              0                5.73                  88.53
# 4         1.0              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %% [markdown]
# # 2

# %%
df.index=df["Unnamed: 0"]
df=df.drop(columns=["Unnamed: 0"])

# %%
df.head()
# Out:
#            Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# Unnamed: 0
# 0             Afghanistan      36263   1269      25198    9796      106.0
# 1                 Albania       4880    144       2745    1991      117.0
# 2                 Algeria      27973   1163      18837    7973      616.0
# 3                 Andorra        907     52        803      52       10.0
# 4                  Angola        950     41        242     667       18.0
#
#             New deaths  New recovered  Deaths / 100 Cases  \
# Unnamed: 0
# 0                 10.0             18                3.50
# 1                  6.0             63                2.95
# 2                  8.0            749                4.16
# 3                  0.0              0                5.73
# 4                  1.0              0                4.32
#
#             Recovered / 100 Cases  Deaths / 100 Recovered  \
# Unnamed: 0
# 0                           69.49                    5.04
# ...

# %% [markdown]
# # 3

# %%
df.index.name='Index'
df.head()
# Out:
#       Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# Index
# 0        Afghanistan      36263   1269      25198    9796      106.0
# 1            Albania       4880    144       2745    1991      117.0
# 2            Algeria      27973   1163      18837    7973      616.0
# 3            Andorra        907     52        803      52       10.0
# 4             Angola        950     41        242     667       18.0
#
#        New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Index
# 0            10.0             18                3.50                  69.49
# 1             6.0             63                2.95                  56.25
# 2             8.0            749                4.16                  67.34
# 3             0.0              0                5.73                  88.53
# 4             1.0              0                4.32                  25.47
#
#        Deaths / 100 Recovered  Confirmed last week  1 week change  \
# Index
# ...

# %% [markdown]
# # 4

# %%
def replace_whitespace(col):
    return col.str.split().str.join("_")

df["WHO Region"]=replace_whitespace(df["WHO Region"])

# %%
df.head(10)
# Out:
#             Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# Index
# 0              Afghanistan      36263   1269      25198    9796      106.0
# 1                  Albania       4880    144       2745    1991      117.0
# 2                  Algeria      27973   1163      18837    7973      616.0
# 3                  Andorra        907     52        803      52       10.0
# 4                   Angola        950     41        242     667       18.0
# 5      Antigua and Barbuda         86      3         65      18        4.0
# 6                Argentina     167416   3059      72575   91782     4890.0
# 7                  Armenia      37390    711      26665   10014       73.0
# 8                Australia      15303    167       9311    5825      368.0
# 9                  Austria      20558    713      18246    1599       86.0
#
#        New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Index
# ...

# %% [markdown]
# # 5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    object
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               177 non-null    float64
#  6   New deaths              177 non-null    float64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    object
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country/Region             0
# Confirmed                  0
# Deaths                     0
# Recovered                  0
# Active                     0
# New cases                 10
# New deaths                10
# New recovered              0
# Deaths / 100 Cases         0
# Recovered / 100 Cases      0
# Deaths / 100 Recovered     0
# Confirmed last week        0
# 1 week change              0
# 1 week % increase          0
# WHO Region                 0
# dtype: int64

# %% [markdown]
# # 6

# %%
mean=df["New cases"].mean()
df["New cases"].fillna(mean,inplace=True)

mean=df["New deaths"].mean()
df["New deaths"].fillna(mean,inplace=True)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_25764\225480889.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["New deaths"].fillna(mean,inplace=True)

# %%
df.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %% [markdown]
# # 7

# %%
len(df["Country/Region"].unique()) #1st approach
df["Country/Region"].nunique() #2nd approach
# Out:
# 187

# %% [markdown]
# # 8

# %%
df["Country/Region"].duplicated().sum()
# Out:
# 0

# %%
# if there is a duplicate then
#df.drop_duplicates(subset="Country/Region",keep='first')

# %% [markdown]
# # 9

# %%
print("The standard deviation is:", df["Confirmed"].describe()['std'])
print("The mean is:", df["Confirmed"].mean())
print("The meadian is:", df["Confirmed"].median())
# Out:
# The standard deviation is: 383318.66383061546
# The mean is: 88130.935828877
# The meadian is: 5059.0

# %% [markdown]
# # 10,11

# %%
import numpy as np
def str_to_int(x):
    try:
        return int(float(x)) 
    except (ValueError, TypeError):
        return np.nan  

df['Deaths']=df["Deaths"].apply(str_to_int)

# %%
df.Deaths.fillna(df.Deaths.mean(),inplace=True)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_25764\1292400867.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Deaths.fillna(df.Deaths.mean(),inplace=True)

# %%
df.Deaths
# Out:
# Index
# 0      1269.000000
# 1       144.000000
# 2      1163.000000
# 3        52.000000
# 4        41.000000
#           ...
# 182      78.000000
# 183       1.000000
# 184     483.000000
# 185     140.000000
# 186    3516.129032
# Name: Deaths, Length: 187, dtype: float64

# %% [markdown]
# # 11(2)

# %%
df['Deaths']=df['Deaths'].astype('str')

# %%
df['Deaths']=df['Deaths'].astype('float')

# %%
df.Deaths
# Out:
# Index
# 0      1269.000000
# 1       144.000000
# 2      1163.000000
# 3        52.000000
# 4        41.000000
#           ...
# 182      78.000000
# 183       1.000000
# 184     483.000000
# 185     140.000000
# 186    3516.129032
# Name: Deaths, Length: 187, dtype: float64

# %% [markdown]
# # 12

# %%
print('the total number of deaths are:',int(df.Deaths.sum()))
print('the total number of recoveries are:',int(df.Recovered.sum()))
# Out:
# the total number of deaths are: 657516
# the total number of recoveries are: 9468087

# %% [markdown]
# # 13

# %%
countries=df['Country/Region'][df.Confirmed>1000000]
print('total contries with  more than 1 million total cases:',len(countries))
# Out:
# total contries with  more than 1 million total cases: 3

# %% [markdown]
# # 14

# %%
df['Recovered / 100 Cases']
# Out:
# Index
# 0      69.49
# 1      56.25
# 2      67.34
# 3      88.53
# 4      25.47
#        ...
# 182    35.33
# 183    80.00
# 184    49.26
# 185    61.84
# 186    20.04
# Name: Recovered / 100 Cases, Length: 187, dtype: float64

# %%
countries=df['Country/Region'][df['Recovered']//df['Confirmed']>0.95]
countries
len(countries)
# Out:
# 3

# %% [markdown]
# # 15

# %%
df=df.drop(columns=['WHO Region','Confirmed'])

# %%
df
# Out:
#            Country/Region       Deaths  Recovered  Active  New cases  \
# Index
# 0             Afghanistan  1269.000000      25198    9796      106.0
# 1                 Albania   144.000000       2745    1991      117.0
# 2                 Algeria  1163.000000      18837    7973      616.0
# 3                 Andorra    52.000000        803      52       10.0
# 4                  Angola    41.000000        242     667       18.0
# ...                   ...          ...        ...     ...        ...
# 182    West Bank and Gaza    78.000000       3752    6791      152.0
# 183        Western Sahara     1.000000          8       1        0.0
# 184                 Yemen   483.000000        833     375       10.0
# 185                Zambia   140.000000       2815    1597       71.0
# 186              Zimbabwe  3516.129032        542    2126      192.0
#
#        New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Index
# ...

# %% [markdown]
# # 16

# %%
countries=df['Country/Region'][df['Deaths']==df.Deaths.max()]

# %%
countries
# Out:
# Index
# 173    US
# Name: Country/Region, dtype: object

# %% [markdown]
# # 17

# %%
df.sort_values(by='Deaths',ascending=False)
# Out:
#          Country/Region    Deaths  Recovered   Active     New cases  \
# Index
# 173                  US  148011.0    1325804  2816444  56336.000000
# 23               Brazil   87618.0    1846641   508116  23284.000000
# 177      United Kingdom   45844.0       1437   254427    688.000000
# 111              Mexico   44022.0     303810    47657   4973.000000
# 85                Italy   35112.0     198593    12581    168.000000
# ...                 ...       ...        ...      ...           ...
# 19               Bhutan       0.0         86       13   1282.740113
# 130    Papua New Guinea       0.0         11       51      0.000000
# 75             Holy See       0.0         12        0      0.000000
# 30             Cambodia       0.0        147       79      1.000000
# 114            Mongolia       0.0        222       67      1.000000
#
#        New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Index
# ...

# %% [markdown]
# # 18

# %%
df['Total_cases']=df.Deaths+df.Recovered+df.Active

# %%
df
# Out:
#            Country/Region       Deaths  Recovered  Active  New cases  \
# Index
# 0             Afghanistan  1269.000000      25198    9796      106.0
# 1                 Albania   144.000000       2745    1991      117.0
# 2                 Algeria  1163.000000      18837    7973      616.0
# 3                 Andorra    52.000000        803      52       10.0
# 4                  Angola    41.000000        242     667       18.0
# ...                   ...          ...        ...     ...        ...
# 182    West Bank and Gaza    78.000000       3752    6791      152.0
# 183        Western Sahara     1.000000          8       1        0.0
# 184                 Yemen   483.000000        833     375       10.0
# 185                Zambia   140.000000       2815    1597       71.0
# 186              Zimbabwe  3516.129032        542    2126      192.0
#
#        New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Index
# ...

# %% [markdown]
# # 19

# %%
df["Death Rate"]=(df.Deaths/df.Confirmed)*100
# can't be done bcz we deleted the Confirmed coloum above

# %% [markdown]
# # 20

# %%
# can't be done bcz we deleted the Confirmed coloum above

# %% [markdown]
# # 21

# %%
df[['Country/Region','Death Rate']].head()

# %% [markdown]
# # 22

# %%
#using the old data set coz the new one doesn't have Confirmed deaths column in it.
df1=pd.DataFrame()
df1=pd.read_csv("C:/Saylani stuff/covid_19_country_wise_latest.csv")
import seaborn as sns
sns.scatterplot(x=df1["Confirmed"], y=df1["Deaths"], color="blue", s=100, alpha=0.7, edgecolor="black", marker="o")
# Out:
# <Axes: xlabel='Confirmed', ylabel='Deaths'>

# %%
df.to_csv("covid_worked_data.csv")
